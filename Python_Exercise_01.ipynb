# %% [markdown]
# <a href="https://colab.research.google.com/github/FedeMaye/DOM/blob/main/Python_Exercise_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1er Ejercicio de Python

# %%
nota_1 = int(input("Nota 1: "))
nota_2 = int(input("Nota 2: "))
nota_3 = int(input("Nota 3: "))

nota_final = (nota_1 * 0.20 + nota_2 * 0.30 + nota_3 * 0.50)

print(f"La nota final es: {nota_final}")
# Out:
# Nota 1: 10
# Nota 2: 9
# Nota 3: 9
# La nota final es: 9.2

# %% [markdown]
# 2do Ejercicio de Python![image.png](data:image/png;base64,...)
